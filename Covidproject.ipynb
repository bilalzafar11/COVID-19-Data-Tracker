# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid=pd.read_csv('owid-covid-data.csv')

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
covid = covid[['location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'people_vaccinated']]
covid.dropna(subset=['total_cases'])
covid.head()
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths  \
# 0  Afghanistan  2020-01-05          0.0        0.0           0.0         0.0
# 1  Afghanistan  2020-01-06          0.0        0.0           0.0         0.0
# 2  Afghanistan  2020-01-07          0.0        0.0           0.0         0.0
# 3  Afghanistan  2020-01-08          0.0        0.0           0.0         0.0
# 4  Afghanistan  2020-01-09          0.0        0.0           0.0         0.0
#
#    people_vaccinated
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
countries=['Pakistan' , 'India' , 'United State' , 'Brazil']
covid=covid[covid['location'].isin(countries)]
covid.head()
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths  \
# 50234   Brazil  2020-01-05          0.0        0.0           0.0         0.0
# 50235   Brazil  2020-01-06          0.0        0.0           0.0         0.0
# 50236   Brazil  2020-01-07          0.0        0.0           0.0         0.0
# 50237   Brazil  2020-01-08          0.0        0.0           0.0         0.0
# 50238   Brazil  2020-01-09          0.0        0.0           0.0         0.0
#
#        people_vaccinated
# 50234                NaN
# 50235                NaN
# 50236                NaN
# 50237                NaN
# 50238                NaN

# %%
sns.lineplot(data=pivot_cases)
plt.title('Total COVID-19 new cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend(title='Country')
plt.show()

# %%
covid['date']=pd.to_datetime(covid['date'])
# Out:
#        iso_code      continent  location       date  total_cases  new_cases  \
# 50234       BRA  South America    Brazil 2020-01-05          0.0        0.0
# 50235       BRA  South America    Brazil 2020-01-06          0.0        0.0
# 50236       BRA  South America    Brazil 2020-01-07          0.0        0.0
# 50237       BRA  South America    Brazil 2020-01-08          0.0        0.0
# 50238       BRA  South America    Brazil 2020-01-09          0.0        0.0
# ...         ...            ...       ...        ...          ...        ...
# 292642      PAK           Asia  Pakistan 2024-07-31    1580631.0        0.0
# 292643      PAK           Asia  Pakistan 2024-08-01    1580631.0        0.0
# 292644      PAK           Asia  Pakistan 2024-08-02    1580631.0        0.0
# 292645      PAK           Asia  Pakistan 2024-08-03    1580631.0        0.0
# 292646      PAK           Asia  Pakistan 2024-08-04    1580631.0        0.0
#
# ...

# %%
pivot_deaths = covid.pivot_table(index='date', columns='location', values='total_deaths')
pivot_cases = covid.pivot_table(index='date', columns='location', values='total_cases')

# %%
# Out:
# location        Brazil       India   Pakistan
# date
# 2020-01-05         0.0         0.0        0.0
# 2020-01-06         0.0         0.0        0.0
# 2020-01-07         0.0         0.0        0.0
# 2020-01-08         0.0         0.0        0.0
# 2020-01-09         0.0         0.0        0.0
# ...                ...         ...        ...
# 2024-07-31  37511921.0  45041435.0  1580631.0
# 2024-08-01  37511921.0  45041435.0  1580631.0
# 2024-08-02  37511921.0  45041435.0  1580631.0
# 2024-08-03  37511921.0  45041435.0  1580631.0
# 2024-08-04  37511921.0  45041748.0  1580631.0
#
# [1674 rows x 3 columns]

# %%
sns.lineplot(data=pivot_cases)
plt.title('Total COVID-19 new cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend(title='Country')
plt.show()

# %%
plt.figure(figsize=(12,6))

# %%
sns.lineplot(data=pivot_deaths)
plt.title('Total COVID-19 death Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend(title='Country')
plt.show()

# %%
sns.lineplot(data=pivot_cases)
plt.title('Total COVID-19 new cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend(title='Country')
plt.show()

# %%
sns.lineplot(data=pivot_cases
plt.title('Total COVID-19 total cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend(title='Country')
plt.show()

# %%
plt.figure(figsize=(12,6))

# %%
for country in countries:
    sns.lineplot(data=covid[covid['location']==country],label=country,x='date',y='new_cases')
    plt.title('New COVID-19 Cases per Day')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()

# %%
latest_data = covid[covid['date'] == covid['date'].max()]
sns.lineplot(data=latest_data, x='location', y='total_deaths')
plt.title('Total Deaths by Country (Latest)')
plt.xlabel('Country')
plt.ylabel('Total Deaths')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=covid, x='date', y='people_vaccinated', hue='location')
plt.title('Vaccination Progress Over Time')
plt.ylabel('People Vaccinated')
plt.show()

# %%
corr_covid = covid[['total_cases', 'total_deaths', 'people_vaccinated']].corr()
sns.heatmap(corr_covid, annot=True)
plt.title('Correlation Heatmap')
plt.show()
